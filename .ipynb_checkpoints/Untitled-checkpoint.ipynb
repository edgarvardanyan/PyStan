# %%
import numpy as np

# %%
a = np.random.multivariate_normal([0,0], [[1,1],[2,4]], 100)

# %%
a
# Out:
# array([[ 2.50125735,  5.00251468],
#        [ 1.17867955,  2.35735908],
#        [-0.09620762, -0.1924152 ],
#        [ 0.21530387,  0.43060769],
#        [-0.51599319, -1.03198643],
#        [-0.5325278 , -1.06505563],
#        [-1.59241622, -3.18483246],
#        [ 1.35596744,  2.71193488],
#        [-0.77586787, -1.55173572],
#        [ 0.72697247,  1.45394495],
#        [-0.21782282, -0.43564567],
#        [ 0.06018836,  0.12037671],
#        [ 0.04929057,  0.09858114],
#        [-1.0553055 , -2.11061105],
#        [-1.01783651, -2.03567302],
#        [-1.44548165, -2.89096331],
#        [-1.18621261, -2.37242521],
#        [-0.98324238, -1.96648478],
#        [ 0.73591103,  1.47182209],
#        [ 0.03579116,  0.07158228],
#        [-1.43582239, -2.87164476],
#        [-0.41951901, -0.83903799],
#        [-0.71635251, -1.43270504],
#        [ 1.52481962,  3.04963925],
#        [ 0.3833838 ,  0.7667676 ],
#        [ 0.53770764,  1.07541528],
#        [ 0.75868192,  1.51736388],
# ...
